# %%
import numpy as np
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_path = r'C:\Users\yugandhar yelai\Cats-And-Dogs\train'
valid_path = r'C:\Users\yugandhar yelai\Cats-And-Dogs\validation'
test_path = r'C:\Users\yugandhar yelai\Cats-And-Dogs\test'

# %%
train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(224,224), classes=['dog', 'cat'], batch_size=10)
valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(224,224), classes=['dog', 'cat'], batch_size=4)
test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(224,224), classes=['dog', 'cat'], batch_size=10)
# Out:
# Found 681 images belonging to 2 classes.
# Found 43 images belonging to 2 classes.
# Found 52 images belonging to 2 classes.

# %%
def prepare(filepath):
    IMG_SIZE = 70
    img_arr = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    #new_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
    return img_arr.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
def plots(ims, figsize=(12,6), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims)%2 ==0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis("Off")
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
            plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
imgs, lables = next(train_batches)

# %%
plots(imgs, titles=lables)

# %% [markdown]
# <B><h4>Build and train CNN</B>

# %%
model = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(224,224,3)),
          Flatten(),
          Dense(2, activation="softmax"),
])

# %%
model.compile(Adam(lr=.0001), loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit_generator(train_batches, steps_per_epoch=5,
                   validation_data=valid_batches, validation_steps=4, epochs=6, verbose=2)
# Out:
# Epoch 1/6
#  - 3s - loss: 35.6960 - accuracy: 0.8000 - val_loss: 144.3886 - val_accuracy: 0.4375
# Epoch 2/6
#  - 2s - loss: 9.7673 - accuracy: 0.8600 - val_loss: 0.0000e+00 - val_accuracy: 0.8125
# Epoch 3/6
#  - 2s - loss: 17.1518 - accuracy: 0.8200 - val_loss: 140.4152 - val_accuracy: 0.5333
# Epoch 4/6
#  - 2s - loss: 33.8751 - accuracy: 0.8200 - val_loss: 50.3456 - val_accuracy: 0.4375
# Epoch 5/6
#  - 2s - loss: 131.5744 - accuracy: 0.6400 - val_loss: 223.6460 - val_accuracy: 0.4375
# Epoch 6/6
#  - 2s - loss: 38.3348 - accuracy: 0.8000 - val_loss: 316.0736 - val_accuracy: 0.4000

# %% [markdown]
# <B><h5>Predict

# %%
test_imgs, test_lables = next(test_batches)
plots(test_imgs, titles=test_lables)
# Out:
# C:\Users\yugandhar yelai\Anaconda3\envs\tensor\lib\site-packages\matplotlib\text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
test_lables = test_lables[:,0]
test_lables
# Out:
# array([1., 0., 1., 1., 1., 1., 0., 0., 0., 1.], dtype=float32)

# %%
prediction = model.predict_generator(test_batches, steps=1, verbose=0)

# %%
prediction
# Out:
# array([[1.000000e+00, 2.789849e-19],
#        [1.000000e+00, 0.000000e+00],
#        [1.000000e+00, 0.000000e+00],
#        [0.000000e+00, 1.000000e+00],
#        [0.000000e+00, 1.000000e+00],
#        [0.000000e+00, 1.000000e+00],
#        [0.000000e+00, 1.000000e+00],
#        [0.000000e+00, 1.000000e+00],
#        [0.000000e+00, 1.000000e+00],
#        [0.000000e+00, 1.000000e+00]], dtype=float32)

# %%
cm = confusion_matrix(test_lables, prediction[:,0])

# %%
CATEGORIES = ['cat', 'dog']

# %%
for i in prediction:
    print(CATEGORIES[int(i[1])])
# Out:
# cat
# cat
# cat
# dog
# dog
# dog
# dog
# dog
# dog
# dog

# %%
def plot_confusion_matrix(cm, classes, normalize=False,
                         title='Confusion matrix',
                         cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
        print("Normalized Confusion Matrix")
    else:
        print("Confusion matrix, without Normalization")
        
    print(cm)
    thresh = cm.max()/2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel("True Label")
    plt.xlabel("Predicted Lable")

# %%
cm_plot_lables = ['cat', 'dog']
plot_confusion_matrix(cm, cm_plot_lables, title="Confusion Matrix")
# Out:
# Confusion matrix, without Normalization
# [[3 1]
#  [4 2]]

# %% [markdown]
# <B><l>BUILD FINE-TUNED VGG16 MODEL

# %%
vgg16_model = keras.applications.vgg16.VGG16()
# Out:
# ...
# 553467904/553467096 [==============================] - 1113s 2us/step

# %%
vgg16_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
type(vgg16_model)
# Out:
# keras.engine.training.Model

# %%
model = Sequential()
for layers in vgg16_model.layers:
    model.add(layers)

# %%
type(model)
# Out:
# keras.engine.sequential.Sequential
